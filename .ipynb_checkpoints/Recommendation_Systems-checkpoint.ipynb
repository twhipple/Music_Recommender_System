# %% [markdown]
# # Recommendation System

# %% [markdown]
# # Libraries

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# # Data

# %%
# Look at artists data
df = pd.read_csv("Data/data_by_artist.csv")
df.head()
# Out:
#                                              artists  acousticness  \
# 0                   "Cats" 1981 Original London Cast      0.598500
# 1                          "Cats" 1983 Broadway Cast      0.862538
# 2        "Fiddler On The Roof” Motion Picture Chorus      0.856571
# 3     "Fiddler On The Roof” Motion Picture Orchestra      0.884926
# 4  "Joseph And The Amazing Technicolor Dreamcoat"...      0.510714
#
#    danceability    duration_ms    energy  instrumentalness  liveness  \
# 0      0.470100  267072.000000  0.376203          0.010261  0.283050
# 1      0.441731  287280.000000  0.406808          0.081158  0.315215
# 2      0.348286  328920.000000  0.286571          0.024593  0.325786
# 3      0.425074  262890.962963  0.245770          0.073587  0.275481
# 4      0.467143  270436.142857  0.488286          0.009400  0.195000
#
#     loudness  speechiness       tempo   valence  popularity  key  mode  count
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32539 entries, 0 to 32538
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   artists           32539 non-null  object
#  1   acousticness      32539 non-null  float64
#  2   danceability      32539 non-null  float64
#  3   duration_ms       32539 non-null  float64
#  4   energy            32539 non-null  float64
#  5   instrumentalness  32539 non-null  float64
#  6   liveness          32539 non-null  float64
#  7   loudness          32539 non-null  float64
#  8   speechiness       32539 non-null  float64
#  9   tempo             32539 non-null  float64
#  10  valence           32539 non-null  float64
#  11  popularity        32539 non-null  float64
#  12  key               32539 non-null  int64
#  13  mode              32539 non-null  int64
#  14  count             32539 non-null  int64
# dtypes: float64(11), int64(3), object(1)
# ...

# %%
# Rename the column count for sake of confusion
df = df.rename(columns={"count": "play_count"})

# %%
df.describe()
# Out:
#        acousticness  danceability   duration_ms        energy  \
# count  32539.000000  32539.000000  3.253900e+04  32539.000000
# mean       0.455682      0.552737  2.485982e+05      0.525908
# std        0.383678      0.176445  1.581808e+05      0.267402
# min        0.000000      0.000000  8.042000e+03      0.000000
# 25%        0.055155      0.436487  1.804616e+05      0.299000
# 50%        0.391833      0.563000  2.215070e+05      0.537375
# 75%        0.876000      0.684500  2.815870e+05      0.747039
# max        0.996000      0.987000  4.696690e+06      1.000000
#
#        instrumentalness      liveness      loudness   speechiness  \
# count      32539.000000  32539.000000  32539.000000  32539.000000
# mean           0.233281      0.209035    -11.008171      0.092047
# std            0.334487      0.151781      5.568630      0.111257
# min            0.000000      0.000000    -60.000000      0.000000
# 25%            0.000012      0.109000    -13.792500      0.039700
# ...

# %%
# Look at artists by popularity
df.groupby(['popularity','artists']).size().reset_index(name='counts').tail(10)
# Out:
#        popularity          artists  counts
# 32529        86.0             Nuka       1
# 32530        86.0        Surf Mesa       1
# 32531        87.0            KIDDO       1
# 32532        89.0        Lele Pons       1
# 32533        89.0  Los Legendarios       1
# 32534        89.0      Ritt Momney       1
# 32535        91.0       Joel Corry       1
# 32536        91.0             Juhn       1
# 32537        92.0             Boza       1
# 32538        94.0               CJ       1

# %%
pop_artists = df.groupby(['popularity','artists']).size().reset_index(name='counts').tail(10)
plt.figure(figsize=(16,5))
sns.barplot(x=pop_artists.popularity, y=pop_artists.artists, palette='CMRmap')
plt.title('Most Popular Artists', fontsize=18)
plt.ylabel('Artists', fontsize=12)
plt.xlabel('Popularity', fontsize=12)
plt.show()

# %%
count_artists = df.groupby(['count','artists']).size().reset_index(name='number').tail(10)
count_artists
# Out:
#        count                   artists  number
# 32529   1086            Billie Holiday       1
# 32530   1117     Wiener Philharmoniker       1
# 32531   1156          Arturo Toscanini       1
# 32532   1202         Vladimir Horowitz       1
# 32533   1248           Ignacio Corsini       1
# 32534   1435             Frank Sinatra       1
# 32535   2124         Эрих Мария Ремарк       1
# 32536   2350          Эрнест Хемингуэй       1
# 32537   2562  Tadeusz Dolega Mostowicz       1
# 32538   3179          Francisco Canaro       1

# %%
count_artists.plot(kind='barh', x='artists', legend=None)
plt.title('Most Listend to Artists', fontsize=18)
plt.ylabel('Artists', fontsize=12)
plt.xlabel('Song Count', fontsize=12)
plt.show()

# %%
artists_count = df.groupby(['count','artists']).size().reset_index(name='number').tail(10)
artists_count
# Out:
#        count                   artists  number
# 32529   1086            Billie Holiday       1
# 32530   1117     Wiener Philharmoniker       1
# 32531   1156          Arturo Toscanini       1
# 32532   1202         Vladimir Horowitz       1
# 32533   1248           Ignacio Corsini       1
# 32534   1435             Frank Sinatra       1
# 32535   2124         Эрих Мария Ремарк       1
# 32536   2350          Эрнест Хемингуэй       1
# 32537   2562  Tadeusz Dolega Mostowicz       1
# 32538   3179          Francisco Canaro       1

# %%
artists_count.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 32529 to 32538
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   count    10 non-null     int64
#  1   artists  10 non-null     object
#  2   number   10 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 372.0+ bytes

# %%
lst1 = [1086,1117,1156,1202,1248,1435,2124,2350,2562,3179]
lst2 = ['Billie Holiday','Wiener Philharmoniker','Arturo Toscanini','Vladimir Horowitz','Ignacio Corsini',
        'Frank Sinatra','Эрих Мария Ремарк','Эрнест Хемингуэй','Tadeusz Dolega Mostowicz','Francisco Canaro']

# %%
art_cnt = pd.DataFrame({'Listens' : lst1,
                        'Artists' : lst2}, 
                        columns=['Listens','Artists'])
art_cnt
# Out:
#    Listens                   Artists
# 0     1086            Billie Holiday
# 1     1117     Wiener Philharmoniker
# 2     1156          Arturo Toscanini
# 3     1202         Vladimir Horowitz
# 4     1248           Ignacio Corsini
# 5     1435             Frank Sinatra
# 6     2124         Эрих Мария Ремарк
# 7     2350          Эрнест Хемингуэй
# 8     2562  Tadeusz Dolega Mostowicz
# 9     3179          Francisco Canaro

# %%
plt.figure(figsize=(16,5))
sns.barplot(x=art_cnt.Listens, y=art_cnt.Artists, palette='CMRmap')
plt.title('Most Listened to Artists', fontsize=18)
plt.ylabel('Artists', fontsize=12)
plt.xlabel('Listens', fontsize=12)
plt.show()

# %%
pop_artists = artists_grp[['popularity']].sum().sort_values(by=['popularity'], ascending=False)[:10]
pop_artists
# Out:
#                  popularity
# artists
# CJ                     94.0
# Boza                   92.0
# Joel Corry             91.0
# Juhn                   91.0
# Ritt Momney            89.0
# Lele Pons              89.0
# Los Legendarios        89.0
# KIDDO                  87.0
# Nuka                   86.0
# Jerry Di               86.0

# %%
plt.figure(figsize=(16,5))
sns.barplot(x=pop_artists.popularity, y=pop_artists.index, palette='CMRmap_r')
plt.title('Most Popular to Artists', fontsize=18)
plt.ylabel('Artists', fontsize=12)
plt.xlabel('Popularity', fontsize=12)
plt.show()

# %%
# finding correlation
corr = df.corr()
# visualizing correlaiton with heatmap
plt.figure(figsize=(20,8))
sns.heatmap(corr, vmax=1, vmin=-1, center=0,linewidth=.5,square=True, 
            annot = True, annot_kws = {'size':8},fmt='.1f', cmap='CMRmap')
plt.title('Correlation')
plt.show()

# %%
# Look at artists data
df_genres = pd.read_csv("Data/data_w_genres.csv")
df_genres.head(20)
# Out:
#                                               artists  acousticness  \
# 0                    "Cats" 1981 Original London Cast      0.598500
# 1                           "Cats" 1983 Broadway Cast      0.862538
# 2         "Fiddler On The Roof” Motion Picture Chorus      0.856571
# 3      "Fiddler On The Roof” Motion Picture Orchestra      0.884926
# 4   "Joseph And The Amazing Technicolor Dreamcoat"...      0.510714
# 5   "Joseph And The Amazing Technicolor Dreamcoat"...      0.591167
# 6                              "Mama" Helen Teagarden      0.725000
# 7                             "Test for Victor Young"      0.927000
# 8                                 "Weird Al" Yankovic      0.186821
# 9                                              $0dg0d      0.110000
# 10                                               $NOT      0.458167
# 11                                        $atori Zoom      0.239000
# 12                                           $tar$eed      0.037500
# ...

# %%
df_genres.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32539 entries, 0 to 32538
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   artists           32539 non-null  object
#  1   acousticness      32539 non-null  float64
#  2   danceability      32539 non-null  float64
#  3   duration_ms       32539 non-null  float64
#  4   energy            32539 non-null  float64
#  5   instrumentalness  32539 non-null  float64
#  6   liveness          32539 non-null  float64
#  7   loudness          32539 non-null  float64
#  8   speechiness       32539 non-null  float64
#  9   tempo             32539 non-null  float64
#  10  valence           32539 non-null  float64
#  11  popularity        32539 non-null  float64
#  12  key               32539 non-null  int64
#  13  mode              32539 non-null  int64
#  14  count             32539 non-null  int64
#  15  genres            32539 non-null  object
# ...

# %%
fav_artists = df.loc[(df.artists=='Wilco') | (df.artists=='The Beatles') | (df.artists=='Elvis Presley') | (df.artists=='Bruce Springsteen') |
                     (df.artists=='The Rolling Stones')| (df.artists=='Kanye West') | (df.artists=='Taylor Swift')| (df.artists=='Iron Maiden') |
                     (df.artists=='The Police')| (df.artists=='Bob Dylan')]
fav_artists.artists
# Out:
# 3504              Bob Dylan
# 3977      Bruce Springsteen
# 8637          Elvis Presley
# 12608           Iron Maiden
# 15038            Kanye West
# 27507          Taylor Swift
# 27812           The Beatles
# 28860            The Police
# 28976    The Rolling Stones
# 31136                 Wilco
# Name: artists, dtype: object

# %%
fav_art_lst = fav_artists.artists.to_list()
fav_art_lst
# Out:
# ['Bob Dylan',
#  'Bruce Springsteen',
#  'Elvis Presley',
#  'Iron Maiden',
#  'Kanye West',
#  'Taylor Swift',
#  'The Beatles',
#  'The Police',
#  'The Rolling Stones',
#  'Wilco']

# %% [markdown]
# # Scale the data

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
# Get the artists alone
df_y = df.artists
df_y.head()
# Out:
# 0                     "Cats" 1981 Original London Cast
# 1                            "Cats" 1983 Broadway Cast
# 2          "Fiddler On The Roof” Motion Picture Chorus
# 3       "Fiddler On The Roof” Motion Picture Orchestra
# 4    "Joseph And The Amazing Technicolor Dreamcoat"...
# Name: artists, dtype: object

# %%
# Apply scaler to numerical columns
scaler = MinMaxScaler()
X = df.drop('artists', axis=1)
X_scaled = scaler.fit_transform(X)
X_scaled
# Out:
# array([[6.00903614e-01, 4.76291793e-01, 5.52462032e-02, ...,
#         4.54545455e-01, 1.00000000e+00, 2.83196979e-03],
#        [8.66002471e-01, 4.47548905e-01, 5.95561876e-02, ...,
#         4.54545455e-01, 1.00000000e+00, 7.86658276e-03],
#        [8.60011474e-01, 3.52873064e-01, 6.84372126e-02, ...,
#         0.00000000e+00, 1.00000000e+00, 1.88797986e-03],
#        ...,
#        [4.17670683e-01, 6.95035461e-01, 4.45060068e-02, ...,
#         4.54545455e-01, 0.00000000e+00, 3.14663310e-04],
#        [2.89156627e-01, 7.48733536e-01, 5.00011944e-02, ...,
#         1.81818182e-01, 0.00000000e+00, 3.14663310e-04],
#        [5.70281124e-01, 4.52887538e-01, 4.89791513e-02, ...,
#         9.09090909e-01, 1.00000000e+00, 3.14663310e-04]])

# %%
# Check out the column names
X.columns
# Out:
# Index(['acousticness', 'danceability', 'duration_ms', 'energy',
#        'instrumentalness', 'liveness', 'loudness', 'speechiness', 'tempo',
#        'valence', 'popularity', 'key', 'mode', 'play_count'],
#       dtype='object')

# %%
# Put back into a dataframe with column names
df_X = pd.DataFrame(X_scaled, columns = X.columns)
df_X.head()
# Out:
#    acousticness  danceability  duration_ms    energy  instrumentalness  \
# 0      0.600904      0.476292     0.055246  0.376203          0.010261
# 1      0.866002      0.447549     0.059556  0.406808          0.081158
# 2      0.860011      0.352873     0.068437  0.286571          0.024593
# 3      0.888480      0.430673     0.054354  0.245770          0.073587
# 4      0.512765      0.473296     0.055964  0.488286          0.009400
#
#    liveness  loudness  speechiness     tempo   valence  popularity       key  \
# 0  0.287069  0.719076     0.215396  0.519161  0.359398    0.406383  0.454545
# 1  0.319691  0.778165     0.181474  0.468738  0.269674    0.335516  0.454545
# 2  0.330411  0.706508     0.122054  0.351976  0.355925    0.367781  0.000000
# 3  0.279393  0.700059     0.126880  0.403341  0.373149    0.366036  0.000000
# 4  0.197769  0.785319     0.101486  0.558769  0.483737    0.446809  0.454545
#
#    mode  play_count
# 0   1.0    0.002832
# 1   1.0    0.007867
# ...

# %%
# Merge the artists with scaled data
final_df = pd.merge(df_y, df_X, left_index=True, right_index=True)
final_df.head()
# Out:
#                                              artists  acousticness  \
# 0                   "Cats" 1981 Original London Cast      0.600904
# 1                          "Cats" 1983 Broadway Cast      0.866002
# 2        "Fiddler On The Roof” Motion Picture Chorus      0.860011
# 3     "Fiddler On The Roof” Motion Picture Orchestra      0.888480
# 4  "Joseph And The Amazing Technicolor Dreamcoat"...      0.512765
#
#    danceability  duration_ms    energy  instrumentalness  liveness  loudness  \
# 0      0.476292     0.055246  0.376203          0.010261  0.287069  0.719076
# 1      0.447549     0.059556  0.406808          0.081158  0.319691  0.778165
# 2      0.352873     0.068437  0.286571          0.024593  0.330411  0.706508
# 3      0.430673     0.054354  0.245770          0.073587  0.279393  0.700059
# 4      0.473296     0.055964  0.488286          0.009400  0.197769  0.785319
#
#    speechiness     tempo   valence  popularity       key  mode  play_count
# ...

# %%
features_df = final_df.drop(['duration_ms','key', 'mode', 'play_count'], axis=1)
features_df.head()
# Out:
#                                              artists  acousticness  \
# 0                   "Cats" 1981 Original London Cast      0.600904
# 1                          "Cats" 1983 Broadway Cast      0.866002
# 2        "Fiddler On The Roof” Motion Picture Chorus      0.860011
# 3     "Fiddler On The Roof” Motion Picture Orchestra      0.888480
# 4  "Joseph And The Amazing Technicolor Dreamcoat"...      0.512765
#
#    danceability    energy  instrumentalness  liveness  loudness  speechiness  \
# 0      0.476292  0.376203          0.010261  0.287069  0.719076     0.215396
# 1      0.447549  0.406808          0.081158  0.319691  0.778165     0.181474
# 2      0.352873  0.286571          0.024593  0.330411  0.706508     0.122054
# 3      0.430673  0.245770          0.073587  0.279393  0.700059     0.126880
# 4      0.473296  0.488286          0.009400  0.197769  0.785319     0.101486
#
#       tempo   valence  popularity
# 0  0.519161  0.359398    0.406383
# ...

# %%
final_features = features_df.drop('artists', axis=1)
final_features.head()
# Out:
#    acousticness  danceability    energy  instrumentalness  liveness  loudness  \
# 0      0.600904      0.476292  0.376203          0.010261  0.287069  0.719076
# 1      0.866002      0.447549  0.406808          0.081158  0.319691  0.778165
# 2      0.860011      0.352873  0.286571          0.024593  0.330411  0.706508
# 3      0.888480      0.430673  0.245770          0.073587  0.279393  0.700059
# 4      0.512765      0.473296  0.488286          0.009400  0.197769  0.785319
#
#    speechiness     tempo   valence  popularity
# 0     0.215396  0.519161  0.359398    0.406383
# 1     0.181474  0.468738  0.269674    0.335516
# 2     0.122054  0.351976  0.355925    0.367781
# 3     0.126880  0.403341  0.373149    0.366036
# 4     0.101486  0.558769  0.483737    0.446809

# %%
final_features.columns
# Out:
# Index(['acousticness', 'danceability', 'energy', 'instrumentalness',
#        'liveness', 'loudness', 'speechiness', 'tempo', 'valence',
#        'popularity'],
#       dtype='object')

# %%
#pip install pyspark

# %%
# import necessary libraries
from pyspark.sql import SparkSession

# %%
# From the notebook of https://www.kaggle.com/akshita72/music-artist-recommender-system

features = ['acousticness', 'danceability', 'energy', 'instrumentalness', 'liveness', 
            'loudness', 'speechiness', 'tempo', 'valence', 'popularity']

def createUserPrefMatrix(artistRatingDict):
    
    artists = artistRatingDict.keys()
    artMat = features_df[features_df['artists'].isin(artists)]
    #print(artMat)
    
    for artist, rating in artistRatingDict.items():
        artMat.loc[artMat['artists']==
                   artist,features] = artMat.loc[artMat['artists']==
                                                 artist,features].mul(rating,axis=0)
    
    userProfile = artMat.loc[:,features].sum(axis=0)
    normalized_userProfile = (userProfile/userProfile.sum())*10
    
    return normalized_userProfile

def createRecomMatrix(userProfile,artists):
    
    artMat = features_df[~features_df['artists'].isin(artists)]
    artMat.set_index('artists',inplace=True) 
    #print(userProfile)
    #print(artMat.head())
    
    recomMat = pd.DataFrame(artMat.values*userProfile.values, 
                            columns=artMat.columns, index=artMat.index)
    recomMat = recomMat.sum(axis=1)
    recomMat.sort_values(ascending = False,inplace=True)
    
    return recomMat

def recommend(artistRatingDict):
    
    userProfile = createUserPrefMatrix(artistRatingDict)
    
    recommendationMat = createRecomMatrix(userProfile,
                                          artistRatingDict.keys()) 
    
    return recommendationMat.head(10)

# %%
artists = fav_art_lst
ratings = [9,8,7,1,2,2,8,7,9,10]
dictionary = dict(zip(artists, ratings))
print(dictionary)
# Out:
# {'Bob Dylan': 9, 'Bruce Springsteen': 8, 'Elvis Presley': 7, 'Iron Maiden': 1, 'Kanye West': 2, 'Taylor Swift': 2, 'The Beatles': 8, 'The Police': 7, 'The Rolling Stones': 9, 'Wilco': 10}

# %%
recommend(dictionary)
# Out:
# /Applications/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1717: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, v)
# artists
# EDDISON                 7.343545
# DJ Mister Cee           7.281511
# KEVVO                   7.217993
# Hampton The Hampster    7.190475
# Lil Mama                7.176760
# Rock D The Legend       7.172005
# Blackowned C-Bone       7.172005
# Banda Los Recoditos     7.168843
# The Jiants              7.167142
# Jonny Bombastic         7.141591
# dtype: float64

# %%
def user_matrix(artist_rating):
    
    artists = artist_rating.keys()
    artMat = data[data['artists'].isin(artists)]
    #print(artMat)
    
    for artist, rating in artist_rating.items():
        artMat.loc[artMat['artists']== artist,final_features.columns] = artMat.loc[artMat['artists']== artist,final_features.columns].mul(rating,axis=0)
    
    userProfile = artMat.loc[:, final_features.columns].sum(axis=0)
    normalized_userProfile = (userProfile/userProfile.sum())*10
    
    return normalized_userProfile

# %%
def createRecomMatrix(userProfile,artists):
    
    artMat = data[~data['artists'].isin(artists)]
    artMat.set_index('artists',inplace=True) 
    #print(userProfile)
    #print(artMat.head())
    
    recomMat = pd.DataFrame(artMat.values*userProfile.values, 
                            columns=artMat.columns, index=artMat.index)
    recomMat = recomMat.sum(axis=1)
    recomMat.sort_values(ascending = False,inplace=True)
    
    return recomMat

# %%
def recommend(artistRatingDict):
    
    userProfile = createUserPrefMatrix(artistRatingDict)
    
    recommendationMat = createRecomMatrix(userProfile,
                                          artistRatingDict.keys()) 
    
    return recommendationMat.head(10)
